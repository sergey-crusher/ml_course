# %% [markdown]
# # Домашнее задание №9: Недообучение и переобучение модели

# %% [markdown]
# ### Вопросы и задания:
# 1. В чём суть недообученной модели и переобученной модели?
# 2. Объясните, почему, казалось бы, точные прогнозы переобученной модели нежелательны, по сравнению с оптимальной, которая демонстрирует больший разброс по ошибкам?

# %% [markdown]
# ### Процесс выполнения:

# %% [markdown]
# 1. Недообученная модель сразу выдаёт довольно большую дисперсию ошибок, которые значительно превышают заданную нами погрешность. При этом следует продолжить её обучать, отсекая, например, шумовые входные данные, оптимизируя алгоритм обучения, фильтрую те значения, которые вносят наибольший шум, но не так существенны и так далее. При переобученной модели ситуация противоположная - результат предсказания на тестовых значениях может достигать 100% точности, однако, при малейшем изменении входных параметров, может возникнуть довольно серьёзная ошибка, которая будет существенно отличаться от оптимальной модели обучения.

# %% [markdown]
# 2. Дело в том, что переобученная модель не способна реагировать на малейшее отклонение от “нормальных” по её мнению, показателей. И любой параметр, который не вписывается в рамки алгоритмов, по которым она обучена, может представлять для неё неразрешимую проблему и, как результат, выдать совершенно неверный показатель на выходе.
